# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd
# Out:
# C:\Users\UPEU

# %%
cd "2020-2 EDIS"
# Out:
# C:\Users\UPEU\2020-2 EDIS

# %%
cd semana14ML
# Out:
# C:\Users\UPEU\2020-2 EDIS\semana14ML

# %%
cd dataset
# Out:
# C:\Users\UPEU\2020-2 EDIS\semana14ML\dataset

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 0C61-E428
#
#  Directorio de C:\Users\UPEU\2020-2 EDIS\semana14ML\dataset
#
# 29/01/2021  12:02 p. m.    <DIR>          .
# 29/01/2021  12:02 p. m.    <DIR>          ..
# 29/01/2021  10:53 a. m.    <DIR>          .ipynb_checkpoints
# 29/01/2021  10:46 a. m.            12,630 ds_cancer.csv
# 29/01/2021  12:02 p. m.            91,065 ds_credit_data.csv
# 29/01/2021  08:29 a. m.            60,411 ds_vehiculos.csv
# 29/01/2021  08:48 a. m.            86,768 ds_vehiculosactualizado.csv
#                4 archivos        250,874 bytes
#                3 dirs  14,826,266,624 bytes libres

# %%
# Estoy accediendo al archivo CSV y copiandolo a un dataframe
dataframe = pd.read_csv('ds_credit_data.csv')

# %%
dataframe.head()
# Out:
#    checking_account_status  duration  credit_history  purpose  credit_amount  \
# 0                       11         6              34       43         1169.0
# 1                       12        48              32       43         5951.0
# 2                       14        12              34       46         2096.0
# 3                       11        42              32       42         7882.0
# 4                       11        24              33       40         4870.0
#
#    savings  present_employment  installment_rate  personal  other_debtors  \
# 0       65                  75               4.0        93            101
# 1       61                  73               2.0        92            101
# 2       61                  74               2.0        93            101
# 3       61                  74               2.0        93            103
# 4       61                  73               3.0        93            101
#
# ...

# %%
# mostramos la ultima columna
dataframe['customer_type']
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2
#       ..
# 995    1
# 996    1
# 997    1
# 998    2
# 999    1
# Name: customer_type, Length: 1000, dtype: int64

# %%
# Sin repitencia
# Es equivalente a distinct (oracle)
dataframe['customer_type'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
dataframe.hist('customer_type')
plt.show()

# %%
print(dataframe.groupby('customer_type').size())
# Out:
# customer_type
# 1    700
# 2    300
# dtype: int64

# %%
# Separamos el dataframe en x y
y = dataframe['customer_type']
x = dataframe.drop('customer_type', axis=1)

# %%
x
# Out:
#      checking_account_status  duration  credit_history  purpose  \
# 0                         11         6              34       43
# 1                         12        48              32       43
# 2                         14        12              34       46
# 3                         11        42              32       42
# 4                         11        24              33       40
# ..                       ...       ...             ...      ...
# 995                       14        12              32       42
# 996                       11        30              32       41
# 997                       14        12              32       43
# 998                       11        45              32       43
# 999                       12        45              34       41
#
#      credit_amount  savings  present_employment  installment_rate  personal  \
# 0           1169.0       65                  75               4.0        93
# ...

# %%
y
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2
#       ..
# 995    1
# 996    1
# 997    1
# 998    2
# 999    1
# Name: customer_type, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=45)

# %%
x_train
# Out:
#      checking_account_status  duration  credit_history  purpose  \
# 640                       11        18              32       46
# 357                       14        36              33       43
# 596                       11        24              32       40
# 833                       12        24              32       43
# 896                       11        21              32       43
# ..                       ...       ...             ...      ...
# 544                       14        12              34       40
# 892                       11        12              34       40
# 643                       14        24              34       43
# 414                       11        24              32       40
# 971                       14        24              32       40
#
#      credit_amount  savings  present_employment  installment_rate  personal  \
# 640          750.0       61                  71               4.0        92
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)

# %%
#Entrenar el algoritmo
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
predicciones = knn.predict(x_test)

# %%
y_test
# Out:
# 726    1
# 243    1
# 342    1
# 976    1
# 919    2
#       ..
# 701    2
# 491    2
# 48     1
# 651    2
# 841    1
# Name: customer_type, Length: 300, dtype: int64

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,predicciones))
print(classification_report(y_test,predicciones))
# Out:
# [[183  23]
#  [ 78  16]]
#               precision    recall  f1-score   support
#
#            1       0.70      0.89      0.78       206
#            2       0.41      0.17      0.24        94
#
#     accuracy                           0.66       300
#    macro avg       0.56      0.53      0.51       300
# weighted avg       0.61      0.66      0.61       300

# %%
tasa_error = []
for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    prediccion_i = knn.predict(x_test)
    tasa_error.append(np.mean(prediccion_i != y_test))

# %%
tasa_error
# Out:
# [0.4166666666666667,
#  0.33666666666666667,
#  0.37,
#  0.32,
#  0.3433333333333333,
#  0.30666666666666664,
#  0.31666666666666665,
#  0.32,
#  0.32,
#  0.31,
#  0.31666666666666665,
#  0.31333333333333335,
#  0.3233333333333333,
#  0.3333333333333333,
#  0.32666666666666666,
#  0.32666666666666666,
#  0.33,
#  0.31666666666666665,
#  0.32,
#  0.31333333333333335,
#  0.31666666666666665,
#  0.30666666666666664,
#  0.3233333333333333,
#  0.31333333333333335,
#  0.3233333333333333,
#  0.32,
#  0.3233333333333333,
#  0.31,
#  0.31666666666666665]

# %%
valores = range(1,30)
plt.plot(valores, tasa_error, color='green', marker='o',markerfacecolor = 'red', markersize='8')

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
predicciones = knn.predict(x_test)
print(confusion_matrix(y_test, predicciones))
print(classification_report(y_test, predicciones))
# Out:
# [[159  47]
#  [ 64  30]]
#               precision    recall  f1-score   support
#
#            1       0.71      0.77      0.74       206
#            2       0.39      0.32      0.35        94
#
#     accuracy                           0.63       300
#    macro avg       0.55      0.55      0.55       300
# weighted avg       0.61      0.63      0.62       300

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(x_train, y_train)
predicciones = knn.predict(x_test)
print(confusion_matrix(y_test, predicciones))
print(classification_report(y_test, predicciones))
# Out:
# [[190  16]
#  [ 80  14]]
#               precision    recall  f1-score   support
#
#            1       0.70      0.92      0.80       206
#            2       0.47      0.15      0.23        94
#
#     accuracy                           0.68       300
#    macro avg       0.59      0.54      0.51       300
# weighted avg       0.63      0.68      0.62       300
